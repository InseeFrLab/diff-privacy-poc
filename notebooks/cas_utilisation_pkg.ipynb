# %%
from stats_dp.request_class import DatasetInfo, Count, Sum, Mean, Ratio, Quantile
from stats_dp.pipeline_class import QueryPipeline
import seaborn as sns
import polars as pl

lf = pl.DataFrame(sns.load_dataset("penguins").dropna()).lazy()

di = DatasetInfo(lf)

lf
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>DF ["species", "island", "bill_length_mm", "bill_depth_mm"]; PROJECT */7 COLUMNS; SELECTION: None</div>

# %% [markdown]
# ## 1. Comptage

# %%
# Out:
# shape: (3, 2)
# ┌───────────┬───────┐
# │ species   ┆ count │
# │ ---       ┆ ---   │
# │ str       ┆ u32   │
# ╞═══════════╪═══════╡
# │ Adelie    ┆ 146   │
# │ Chinstrap ┆ 68    │
# │ Gentoo    ┆ 119   │
# └───────────┴───────┘
# shape: (1, 5)
# ┌────────┬───────────┬──────────────────┬──────────┬──────────┐
# │ column ┆ aggregate ┆ distribution     ┆ scale    ┆ accuracy │
# │ ---    ┆ ---       ┆ ---              ┆ ---      ┆ ---      │
# │ str    ┆ str       ┆ str              ┆ f64      ┆ f64      │
# ╞════════╪═══════════╪══════════════════╪══════════╪══════════╡
# │ count  ┆ Sum       ┆ Integer Gaussian ┆ 2.236068 ┆ 5.0      │
# └────────┴───────────┴──────────────────┴──────────┴──────────┘
# shape: (3, 2)
# ┌───────┬───────────┐
# │ count ┆ species   │
# │ ---   ┆ ---       │
# │ i32   ┆ str       │
# ╞═══════╪═══════════╡
# │ 144   ┆ Adelie    │
# │ 68    ┆ Chinstrap │
# │ 121   ┆ Gentoo    │
# └───────┴───────────┘

# %% [markdown]
# ## 2. Total

# %% [markdown]
# ## 3. Moyenne

# %% [markdown]
# ## 4. Quantile

# %%
requete = Quantile(variable="body_mass_g", bounds=[2700.0, 6300.0],
        alphas=[0.5], step_size=100)
di = DatasetInfo(lf, max_dataset_size_bound = 1000)
di.create_epsilon_context(0.1, weight_list=[1])
print(requete.execute(lf, True))
print(requete.precision_opendp(di))
print(requete.execute_dp(di))
# Out:
# shape: (1, 1)
# ┌──────────────┐
# │ quantile_0.5 │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ 4050.0       │
# └──────────────┘
# shape: (1, 5)
# ┌──────────────┬──────────────┬──────────────┬──────────┬──────────┐
# │ column       ┆ aggregate    ┆ distribution ┆ scale    ┆ accuracy │
# │ ---          ┆ ---          ┆ ---          ┆ ---      ┆ ---      │
# │ str          ┆ str          ┆ str          ┆ f64      ┆ f64      │
# ╞══════════════╪══════════════╪══════════════╪══════════╪══════════╡
# │ quantile_0.5 ┆ 0.5-Quantile ┆ GumbelMin    ┆ 2.236068 ┆ null     │
# └──────────────┴──────────────┴──────────────┴──────────┴──────────┘
# shape: (1, 1)
# ┌──────────────┐
# │ quantile_0.5 │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ 4000.0       │
# └──────────────┘

# %% [markdown]
# # Utilisation du Pipeline

# %%
from src.request_class import Count, Sum, Mean, Ratio, Quantile
import seaborn as sns
import polars as pl

requetes = {
    "req_1": Count(),
    "req_2": Count(by=["species"]),
    "req_3": Count(by=["island", "species"]),
    "req_4": Count(by=["island", "sex", "species"]),
    "req_5": Count(by=["island", "sex"]),
    "req_6": Count(by=["sex"]),
    "req_7": Count(by=["island"]),
    "req_8": Count(by=["sex", "species"]),

    "req_9": Sum(variable="body_mass_g", bounds=[2700.0, 6300.0]),
    "req_10": Sum(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["species"]),
    "req_11": Sum(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["island", "species"]),
    "req_12": Sum(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["island", "sex", "species"]),
    "req_13": Sum(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["island", "sex"]),
    "req_14": Sum(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["sex"]),
    "req_15": Sum(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["sex", "species"]),
    "req_16": Sum(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["island"]),

    "req_17": Mean(variable="body_mass_g", bounds=[2700.0, 6300.0]),
    "req_18": Mean(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["species"]),
    "req_19": Mean(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["island", "species"]),
    "req_20": Mean(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["island", "sex", "species"]),
    "req_21": Mean(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["island", "sex"]),
    "req_22": Mean(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["sex"]),
    "req_23": Mean(variable="body_mass_g", bounds=[2700.0, 6300.0], by=["island"]),

    "req_24": Ratio(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        variable_denominateur="bill_length_mm", bounds_denominateur=[32.1, 59.6],
        by=["species"]
    ),
    "req_25": Ratio(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        variable_denominateur="bill_length_mm", bounds_denominateur=[32.1, 59.6],
        by=["island", "species"]
    ),
    "req_26": Ratio(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        variable_denominateur="bill_length_mm", bounds_denominateur=[32.1, 59.6],
        by=["island", "sex", "species"]
    ),
    "req_27": Ratio(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        variable_denominateur="bill_length_mm", bounds_denominateur=[32.1, 59.6],
        by=["island", "sex"]
    ),
    "req_28": Ratio(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        variable_denominateur="bill_length_mm", bounds_denominateur=[32.1, 59.6],
        by=["sex"]
    ),
    "req_29": Ratio(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        variable_denominateur="bill_length_mm", bounds_denominateur=[32.1, 59.6]
    ),

    "req_30": Quantile(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        alpha=[0.5], nb_candidats="300"
    ),
    "req_31": Quantile(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        by=["species"], alpha=[0.5], nb_candidats="300"
    ),
    "req_32": Quantile(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        by=["island", "sex", "species"], alpha=[0.5], nb_candidats="300"
    ),
    "req_33": Quantile(
        variable="body_mass_g", bounds=[2700.0, 6300.0],
        by=["island", "species"], alpha=[0.5], nb_candidats="300"
    )
}


dict_poids = {key: 1/len(requetes) for key in requetes.keys()}

lf = pl.DataFrame(sns.load_dataset("penguins").dropna()).lazy()

# %%
from src.pipeline_class import Pipeline

pipeline_request = Pipeline(requetes, lf)
pipeline_request.execute()
# Out:
# ==> Début execute
# <== Fin execute (temps total : 0.01 secondes)
# {'req_1': shape: (1, 1)
#  ┌───────┐
#  │ count │
#  │ ---   │
#  │ u32   │
#  ╞═══════╡
#  │ 333   │
#  └───────┘,
#  'req_2': shape: (3, 2)
#  ┌───────────┬───────┐
#  │ species   ┆ count │
#  │ ---       ┆ ---   │
#  │ str       ┆ u32   │
#  ╞═══════════╪═══════╡
#  │ Chinstrap ┆ 68    │
#  │ Adelie    ┆ 146   │
#  │ Gentoo    ┆ 119   │
#  └───────────┴───────┘,
#  'req_3': shape: (5, 3)
#  ┌───────────┬───────────┬───────┐
#  │ island    ┆ species   ┆ count │
#  │ ---       ┆ ---       ┆ ---   │
#  │ str       ┆ str       ┆ u32   │
#  ╞═══════════╪═══════════╪═══════╡
#  │ Biscoe    ┆ Adelie    ┆ 44    │
#  │ Biscoe    ┆ Gentoo    ┆ 119   │
#  │ Dream     ┆ Adelie    ┆ 55    │
#  │ Dream     ┆ Chinstrap ┆ 68    │
#  │ Torgersen ┆ Adelie    ┆ 47    │
#  └───────────┴───────────┴───────┘,
#  'req_4': shape: (10, 4)
#  ┌───────────┬────────┬───────────┬───────┐
#  │ island    ┆ sex    ┆ species   ┆ count │
#  │ ---       ┆ ---    ┆ ---       ┆ ---   │
#  │ str       ┆ str    ┆ str       ┆ u32   │
#  ╞═══════════╪════════╪═══════════╪═══════╡
#  │ Biscoe    ┆ Female ┆ Gentoo    ┆ 58    │
#  │ Biscoe    ┆ Female ┆ Adelie    ┆ 22    │
#  │ Dream     ┆ Female ┆ Chinstrap ┆ 34    │
#  │ Dream     ┆ Male   ┆ Chinstrap ┆ 34    │
#  │ Biscoe    ┆ Male   ┆ Adelie    ┆ 22    │
#  │ Dream     ┆ Male   ┆ Adelie    ┆ 28    │
#  │ Biscoe    ┆ Male   ┆ Gentoo    ┆ 61    │
#  │ Dream     ┆ Female ┆ Adelie    ┆ 27    │
#  │ Torgersen ┆ Female ┆ Adelie    ┆ 24    │
#  │ Torgersen ┆ Male   ┆ Adelie    ┆ 23    │
#  └───────────┴────────┴───────────┴───────┘,
#  'req_5': shape: (6, 3)
#  ┌───────────┬────────┬───────┐
#  │ island    ┆ sex    ┆ count │
#  │ ---       ┆ ---    ┆ ---   │
#  │ str       ┆ str    ┆ u32   │
#  ╞═══════════╪════════╪═══════╡
#  │ Torgersen ┆ Male   ┆ 23    │
#  │ Dream     ┆ Female ┆ 61    │
#  │ Biscoe    ┆ Male   ┆ 83    │
#  │ Torgersen ┆ Female ┆ 24    │
#  │ Biscoe    ┆ Female ┆ 80    │
#  │ Dream     ┆ Male   ┆ 62    │
#  └───────────┴────────┴───────┘,
#  'req_6': shape: (2, 2)
#  ┌────────┬───────┐
#  │ sex    ┆ count │
#  │ ---    ┆ ---   │
#  │ str    ┆ u32   │
#  ╞════════╪═══════╡
#  │ Female ┆ 165   │
#  │ Male   ┆ 168   │
#  └────────┴───────┘,
#  'req_7': shape: (3, 2)
#  ┌───────────┬───────┐
#  │ island    ┆ count │
#  │ ---       ┆ ---   │
#  │ str       ┆ u32   │
#  ╞═══════════╪═══════╡
#  │ Dream     ┆ 123   │
#  │ Biscoe    ┆ 163   │
#  │ Torgersen ┆ 47    │
#  └───────────┴───────┘,
#  'req_8': shape: (6, 3)
#  ┌────────┬───────────┬───────┐
#  │ sex    ┆ species   ┆ count │
#  │ ---    ┆ ---       ┆ ---   │
#  │ str    ┆ str       ┆ u32   │
#  ╞════════╪═══════════╪═══════╡
#  │ Male   ┆ Gentoo    ┆ 61    │
#  │ Female ┆ Adelie    ┆ 73    │
#  │ Male   ┆ Adelie    ┆ 73    │
#  │ Male   ┆ Chinstrap ┆ 34    │
#  │ Female ┆ Gentoo    ┆ 58    │
#  │ Female ┆ Chinstrap ┆ 34    │
#  └────────┴───────────┴───────┘,
#  'req_9': shape: (1, 2)
#  ┌───────────┬───────┐
#  │ sum       ┆ count │
#  │ ---       ┆ ---   │
#  │ f64       ┆ u32   │
#  ╞═══════════╪═══════╡
#  │ 1.40095e6 ┆ 333   │
#  └───────────┴───────┘,
#  'req_10': shape: (3, 3)
#  ┌───────────┬──────────┬───────┐
#  │ species   ┆ sum      ┆ count │
#  │ ---       ┆ ---      ┆ ---   │
#  │ str       ┆ f64      ┆ u32   │
#  ╞═══════════╪══════════╪═══════╡
#  │ Gentoo    ┆ 606000.0 ┆ 119   │
#  │ Chinstrap ┆ 253850.0 ┆ 68    │
#  │ Adelie    ┆ 541100.0 ┆ 146   │
#  └───────────┴──────────┴───────┘,
#  'req_11': shape: (5, 4)
#  ┌───────────┬───────────┬──────────┬───────┐
#  │ island    ┆ species   ┆ sum      ┆ count │
#  │ ---       ┆ ---       ┆ ---      ┆ ---   │
#  │ str       ┆ str       ┆ f64      ┆ u32   │
#  ╞═══════════╪═══════════╪══════════╪═══════╡
#  │ Biscoe    ┆ Gentoo    ┆ 606000.0 ┆ 119   │
#  │ Torgersen ┆ Adelie    ┆ 174300.0 ┆ 47    │
#  │ Biscoe    ┆ Adelie    ┆ 163225.0 ┆ 44    │
#  │ Dream     ┆ Chinstrap ┆ 253850.0 ┆ 68    │
#  │ Dream     ┆ Adelie    ┆ 203575.0 ┆ 55    │
#  └───────────┴───────────┴──────────┴───────┘,
#  'req_12': shape: (10, 5)
#  ┌───────────┬────────┬───────────┬──────────┬───────┐
#  │ island    ┆ sex    ┆ species   ┆ sum      ┆ count │
#  │ ---       ┆ ---    ┆ ---       ┆ ---      ┆ ---   │
#  │ str       ┆ str    ┆ str       ┆ f64      ┆ u32   │
#  ╞═══════════╪════════╪═══════════╪══════════╪═══════╡
#  │ Biscoe    ┆ Male   ┆ Gentoo    ┆ 334575.0 ┆ 61    │
#  │ Dream     ┆ Female ┆ Adelie    ┆ 90300.0  ┆ 27    │
#  │ Torgersen ┆ Male   ┆ Adelie    ┆ 92800.0  ┆ 23    │
#  │ Dream     ┆ Female ┆ Chinstrap ┆ 119925.0 ┆ 34    │
#  │ Torgersen ┆ Female ┆ Adelie    ┆ 81500.0  ┆ 24    │
#  │ Biscoe    ┆ Female ┆ Gentoo    ┆ 271425.0 ┆ 58    │
#  │ Biscoe    ┆ Female ┆ Adelie    ┆ 74125.0  ┆ 22    │
#  │ Biscoe    ┆ Male   ┆ Adelie    ┆ 89100.0  ┆ 22    │
#  │ Dream     ┆ Male   ┆ Adelie    ┆ 113275.0 ┆ 28    │
#  │ Dream     ┆ Male   ┆ Chinstrap ┆ 133925.0 ┆ 34    │
#  └───────────┴────────┴───────────┴──────────┴───────┘,
#  'req_13': shape: (6, 4)
#  ┌───────────┬────────┬──────────┬───────┐
#  │ island    ┆ sex    ┆ sum      ┆ count │
#  │ ---       ┆ ---    ┆ ---      ┆ ---   │
#  │ str       ┆ str    ┆ f64      ┆ u32   │
#  ╞═══════════╪════════╪══════════╪═══════╡
#  │ Biscoe    ┆ Male   ┆ 423675.0 ┆ 83    │
#  │ Dream     ┆ Male   ┆ 247200.0 ┆ 62    │
#  │ Torgersen ┆ Female ┆ 81500.0  ┆ 24    │
#  │ Biscoe    ┆ Female ┆ 345550.0 ┆ 80    │
#  │ Dream     ┆ Female ┆ 210225.0 ┆ 61    │
#  │ Torgersen ┆ Male   ┆ 92800.0  ┆ 23    │
#  └───────────┴────────┴──────────┴───────┘,
#  'req_14': shape: (2, 3)
#  ┌────────┬──────────┬───────┐
#  │ sex    ┆ sum      ┆ count │
#  │ ---    ┆ ---      ┆ ---   │
#  │ str    ┆ f64      ┆ u32   │
#  ╞════════╪══════════╪═══════╡
#  │ Male   ┆ 763675.0 ┆ 168   │
#  │ Female ┆ 637275.0 ┆ 165   │
#  └────────┴──────────┴───────┘,
#  'req_15': shape: (6, 4)
#  ┌────────┬───────────┬──────────┬───────┐
#  │ sex    ┆ species   ┆ sum      ┆ count │
#  │ ---    ┆ ---       ┆ ---      ┆ ---   │
#  │ str    ┆ str       ┆ f64      ┆ u32   │
#  ╞════════╪═══════════╪══════════╪═══════╡
#  │ Female ┆ Gentoo    ┆ 271425.0 ┆ 58    │
#  │ Male   ┆ Adelie    ┆ 295175.0 ┆ 73    │
#  │ Female ┆ Chinstrap ┆ 119925.0 ┆ 34    │
#  │ Male   ┆ Gentoo    ┆ 334575.0 ┆ 61    │
#  │ Female ┆ Adelie    ┆ 245925.0 ┆ 73    │
#  │ Male   ┆ Chinstrap ┆ 133925.0 ┆ 34    │
#  └────────┴───────────┴──────────┴───────┘,
#  'req_16': shape: (3, 3)
#  ┌───────────┬──────────┬───────┐
#  │ island    ┆ sum      ┆ count │
#  │ ---       ┆ ---      ┆ ---   │
#  │ str       ┆ f64      ┆ u32   │
#  ╞═══════════╪══════════╪═══════╡
#  │ Dream     ┆ 457425.0 ┆ 123   │
#  │ Biscoe    ┆ 769225.0 ┆ 163   │
#  │ Torgersen ┆ 174300.0 ┆ 47    │
#  └───────────┴──────────┴───────┘,
#  'req_17': shape: (1, 3)
#  ┌───────────┬───────┬─────────────┐
#  │ sum       ┆ count ┆ mean        │
#  │ ---       ┆ ---   ┆ ---         │
#  │ f64       ┆ u32   ┆ f64         │
#  ╞═══════════╪═══════╪═════════════╡
#  │ 1.40095e6 ┆ 333   ┆ 4207.057057 │
#  └───────────┴───────┴─────────────┘,
#  'req_18': shape: (3, 4)
#  ┌───────────┬──────────┬───────┬─────────────┐
#  │ species   ┆ sum      ┆ count ┆ mean        │
#  │ ---       ┆ ---      ┆ ---   ┆ ---         │
#  │ str       ┆ f64      ┆ u32   ┆ f64         │
#  ╞═══════════╪══════════╪═══════╪═════════════╡
#  │ Gentoo    ┆ 606000.0 ┆ 119   ┆ 5092.436975 │
#  │ Adelie    ┆ 541100.0 ┆ 146   ┆ 3706.164384 │
#  │ Chinstrap ┆ 253850.0 ┆ 68    ┆ 3733.088235 │
#  └───────────┴──────────┴───────┴─────────────┘,
#  'req_19': shape: (5, 5)
#  ┌───────────┬───────────┬──────────┬───────┬─────────────┐
#  │ island    ┆ species   ┆ sum      ┆ count ┆ mean        │
#  │ ---       ┆ ---       ┆ ---      ┆ ---   ┆ ---         │
#  │ str       ┆ str       ┆ f64      ┆ u32   ┆ f64         │
#  ╞═══════════╪═══════════╪══════════╪═══════╪═════════════╡
#  │ Torgersen ┆ Adelie    ┆ 174300.0 ┆ 47    ┆ 3708.510638 │
#  │ Biscoe    ┆ Gentoo    ┆ 606000.0 ┆ 119   ┆ 5092.436975 │
#  │ Dream     ┆ Adelie    ┆ 203575.0 ┆ 55    ┆ 3701.363636 │
#  │ Dream     ┆ Chinstrap ┆ 253850.0 ┆ 68    ┆ 3733.088235 │
#  │ Biscoe    ┆ Adelie    ┆ 163225.0 ┆ 44    ┆ 3709.659091 │
#  └───────────┴───────────┴──────────┴───────┴─────────────┘,
#  'req_20': shape: (10, 6)
#  ┌───────────┬────────┬───────────┬──────────┬───────┬─────────────┐
#  │ island    ┆ sex    ┆ species   ┆ sum      ┆ count ┆ mean        │
#  │ ---       ┆ ---    ┆ ---       ┆ ---      ┆ ---   ┆ ---         │
#  │ str       ┆ str    ┆ str       ┆ f64      ┆ u32   ┆ f64         │
#  ╞═══════════╪════════╪═══════════╪══════════╪═══════╪═════════════╡
#  │ Torgersen ┆ Male   ┆ Adelie    ┆ 92800.0  ┆ 23    ┆ 4034.782609 │
#  │ Dream     ┆ Female ┆ Adelie    ┆ 90300.0  ┆ 27    ┆ 3344.444444 │
#  │ Dream     ┆ Male   ┆ Adelie    ┆ 113275.0 ┆ 28    ┆ 4045.535714 │
#  │ Biscoe    ┆ Female ┆ Adelie    ┆ 74125.0  ┆ 22    ┆ 3369.318182 │
#  │ Torgersen ┆ Female ┆ Adelie    ┆ 81500.0  ┆ 24    ┆ 3395.833333 │
#  │ Biscoe    ┆ Female ┆ Gentoo    ┆ 271425.0 ┆ 58    ┆ 4679.741379 │
#  │ Biscoe    ┆ Male   ┆ Adelie    ┆ 89100.0  ┆ 22    ┆ 4050.0      │
#  │ Dream     ┆ Female ┆ Chinstrap ┆ 119925.0 ┆ 34    ┆ 3527.205882 │
#  │ Biscoe    ┆ Male   ┆ Gentoo    ┆ 334575.0 ┆ 61    ┆ 5484.836066 │
#  │ Dream     ┆ Male   ┆ Chinstrap ┆ 133925.0 ┆ 34    ┆ 3938.970588 │
#  └───────────┴────────┴───────────┴──────────┴───────┴─────────────┘,
#  'req_21': shape: (6, 5)
#  ┌───────────┬────────┬──────────┬───────┬─────────────┐
#  │ island    ┆ sex    ┆ sum      ┆ count ┆ mean        │
#  │ ---       ┆ ---    ┆ ---      ┆ ---   ┆ ---         │
#  │ str       ┆ str    ┆ f64      ┆ u32   ┆ f64         │
#  ╞═══════════╪════════╪══════════╪═══════╪═════════════╡
#  │ Dream     ┆ Male   ┆ 247200.0 ┆ 62    ┆ 3987.096774 │
#  │ Torgersen ┆ Male   ┆ 92800.0  ┆ 23    ┆ 4034.782609 │
#  │ Dream     ┆ Female ┆ 210225.0 ┆ 61    ┆ 3446.311475 │
#  │ Biscoe    ┆ Female ┆ 345550.0 ┆ 80    ┆ 4319.375    │
#  │ Torgersen ┆ Female ┆ 81500.0  ┆ 24    ┆ 3395.833333 │
#  │ Biscoe    ┆ Male   ┆ 423675.0 ┆ 83    ┆ 5104.518072 │
#  └───────────┴────────┴──────────┴───────┴─────────────┘,
#  'req_22': shape: (2, 4)
#  ┌────────┬──────────┬───────┬─────────────┐
#  │ sex    ┆ sum      ┆ count ┆ mean        │
#  │ ---    ┆ ---      ┆ ---   ┆ ---         │
#  │ str    ┆ f64      ┆ u32   ┆ f64         │
#  ╞════════╪══════════╪═══════╪═════════════╡
#  │ Female ┆ 637275.0 ┆ 165   ┆ 3862.272727 │
#  │ Male   ┆ 763675.0 ┆ 168   ┆ 4545.684524 │
#  └────────┴──────────┴───────┴─────────────┘,
#  'req_23': shape: (3, 4)
#  ┌───────────┬──────────┬───────┬─────────────┐
#  │ island    ┆ sum      ┆ count ┆ mean        │
#  │ ---       ┆ ---      ┆ ---   ┆ ---         │
#  │ str       ┆ f64      ┆ u32   ┆ f64         │
#  ╞═══════════╪══════════╪═══════╪═════════════╡
#  │ Biscoe    ┆ 769225.0 ┆ 163   ┆ 4719.171779 │
#  │ Dream     ┆ 457425.0 ┆ 123   ┆ 3718.902439 │
#  │ Torgersen ┆ 174300.0 ┆ 47    ┆ 3708.510638 │
#  └───────────┴──────────┴───────┴─────────────┘,
#  'req_24': shape: (3, 4)
#  ┌───────────┬──────────┬───────────┬────────────┐
#  │ species   ┆ sum_num  ┆ sum_denom ┆ ratio      │
#  │ ---       ┆ ---      ┆ ---       ┆ ---        │
#  │ str       ┆ f64      ┆ f64       ┆ f64        │
#  ╞═══════════╪══════════╪═══════════╪════════════╡
#  │ Adelie    ┆ 541100.0 ┆ 5668.3    ┆ 95.46072   │
#  │ Chinstrap ┆ 253850.0 ┆ 3320.7    ┆ 76.444726  │
#  │ Gentoo    ┆ 606000.0 ┆ 5660.6    ┆ 107.055789 │
#  └───────────┴──────────┴───────────┴────────────┘,
#  'req_25': shape: (5, 5)
#  ┌───────────┬───────────┬──────────┬───────────┬────────────┐
#  │ island    ┆ species   ┆ sum_num  ┆ sum_denom ┆ ratio      │
#  │ ---       ┆ ---       ┆ ---      ┆ ---       ┆ ---        │
#  │ str       ┆ str       ┆ f64      ┆ f64       ┆ f64        │
#  ╞═══════════╪═══════════╪══════════╪═══════════╪════════════╡
#  │ Dream     ┆ Chinstrap ┆ 253850.0 ┆ 3320.7    ┆ 76.444726  │
#  │ Dream     ┆ Adelie    ┆ 203575.0 ┆ 2118.6    ┆ 96.089399  │
#  │ Biscoe    ┆ Gentoo    ┆ 606000.0 ┆ 5660.6    ┆ 107.055789 │
#  │ Torgersen ┆ Adelie    ┆ 174300.0 ┆ 1834.8    ┆ 94.99673   │
#  │ Biscoe    ┆ Adelie    ┆ 163225.0 ┆ 1714.9    ┆ 95.180477  │
#  └───────────┴───────────┴──────────┴───────────┴────────────┘,
#  'req_26': shape: (10, 6)
#  ┌───────────┬────────┬───────────┬──────────┬───────────┬────────────┐
#  │ island    ┆ sex    ┆ species   ┆ sum_num  ┆ sum_denom ┆ ratio      │
#  │ ---       ┆ ---    ┆ ---       ┆ ---      ┆ ---       ┆ ---        │
#  │ str       ┆ str    ┆ str       ┆ f64      ┆ f64       ┆ f64        │
#  ╞═══════════╪════════╪═══════════╪══════════╪═══════════╪════════════╡
#  │ Dream     ┆ Female ┆ Adelie    ┆ 90300.0  ┆ 996.6     ┆ 90.608067  │
#  │ Dream     ┆ Male   ┆ Chinstrap ┆ 133925.0 ┆ 1737.2    ┆ 77.092448  │
#  │ Biscoe    ┆ Male   ┆ Gentoo    ┆ 334575.0 ┆ 3017.9    ┆ 110.863514 │
#  │ Dream     ┆ Male   ┆ Adelie    ┆ 113275.0 ┆ 1122.0    ┆ 100.958111 │
#  │ Torgersen ┆ Female ┆ Adelie    ┆ 81500.0  ┆ 901.3     ┆ 90.424942  │
#  │ Biscoe    ┆ Male   ┆ Adelie    ┆ 89100.0  ┆ 893.0     ┆ 99.776036  │
#  │ Torgersen ┆ Male   ┆ Adelie    ┆ 92800.0  ┆ 933.5     ┆ 99.410819  │
#  │ Biscoe    ┆ Female ┆ Adelie    ┆ 74125.0  ┆ 821.9     ┆ 90.187371  │
#  │ Dream     ┆ Female ┆ Chinstrap ┆ 119925.0 ┆ 1583.5    ┆ 75.734133  │
#  │ Biscoe    ┆ Female ┆ Gentoo    ┆ 271425.0 ┆ 2642.7    ┆ 102.707458 │
#  └───────────┴────────┴───────────┴──────────┴───────────┴────────────┘,
#  'req_27': shape: (6, 5)
#  ┌───────────┬────────┬──────────┬───────────┬────────────┐
#  │ island    ┆ sex    ┆ sum_num  ┆ sum_denom ┆ ratio      │
#  │ ---       ┆ ---    ┆ ---      ┆ ---       ┆ ---        │
#  │ str       ┆ str    ┆ f64      ┆ f64       ┆ f64        │
#  ╞═══════════╪════════╪══════════╪═══════════╪════════════╡
#  │ Torgersen ┆ Female ┆ 81500.0  ┆ 901.3     ┆ 90.424942  │
#  │ Dream     ┆ Male   ┆ 247200.0 ┆ 2859.2    ┆ 86.45775   │
#  │ Biscoe    ┆ Male   ┆ 423675.0 ┆ 3910.9    ┆ 108.331842 │
#  │ Dream     ┆ Female ┆ 210225.0 ┆ 2580.1    ┆ 81.4794    │
#  │ Biscoe    ┆ Female ┆ 345550.0 ┆ 3464.6    ┆ 99.737343  │
#  │ Torgersen ┆ Male   ┆ 92800.0  ┆ 933.5     ┆ 99.410819  │
#  └───────────┴────────┴──────────┴───────────┴────────────┘,
#  'req_28': shape: (2, 4)
#  ┌────────┬──────────┬───────────┬───────────┐
#  │ sex    ┆ sum_num  ┆ sum_denom ┆ ratio     │
#  │ ---    ┆ ---      ┆ ---       ┆ ---       │
#  │ str    ┆ f64      ┆ f64       ┆ f64       │
#  ╞════════╪══════════╪═══════════╪═══════════╡
#  │ Female ┆ 637275.0 ┆ 6946.0    ┆ 91.747049 │
#  │ Male   ┆ 763675.0 ┆ 7703.6    ┆ 99.132224 │
#  └────────┴──────────┴───────────┴───────────┘,
#  'req_29': shape: (1, 3)
#  ┌───────────┬───────────┬───────────┐
#  │ sum_num   ┆ sum_denom ┆ ratio     │
#  │ ---       ┆ ---       ┆ ---       │
#  │ f64       ┆ f64       ┆ f64       │
#  ╞═══════════╪═══════════╪═══════════╡
#  │ 1.40095e6 ┆ 14649.6   ┆ 95.630597 │
#  └───────────┴───────────┴───────────┘,
#  'req_30': shape: (1, 1)
#  ┌──────────────┐
#  │ quantile_0.5 │
#  │ ---          │
#  │ f64          │
#  ╞══════════════╡
#  │ 4050.0       │
#  └──────────────┘,
#  'req_31': shape: (3, 2)
#  ┌───────────┬──────────────┐
#  │ species   ┆ quantile_0.5 │
#  │ ---       ┆ ---          │
#  │ str       ┆ f64          │
#  ╞═══════════╪══════════════╡
#  │ Gentoo    ┆ 5050.0       │
#  │ Adelie    ┆ 3700.0       │
#  │ Chinstrap ┆ 3700.0       │
#  └───────────┴──────────────┘,
#  'req_32': shape: (10, 4)
#  ┌───────────┬────────┬───────────┬──────────────┐
#  │ island    ┆ sex    ┆ species   ┆ quantile_0.5 │
#  │ ---       ┆ ---    ┆ ---       ┆ ---          │
#  │ str       ┆ str    ┆ str       ┆ f64          │
#  ╞═══════════╪════════╪═══════════╪══════════════╡
#  │ Biscoe    ┆ Male   ┆ Gentoo    ┆ 5500.0       │
#  │ Biscoe    ┆ Female ┆ Adelie    ┆ 3400.0       │
#  │ Torgersen ┆ Male   ┆ Adelie    ┆ 4000.0       │
#  │ Dream     ┆ Male   ┆ Chinstrap ┆ 3950.0       │
#  │ Dream     ┆ Female ┆ Adelie    ┆ 3400.0       │
#  │ Biscoe    ┆ Female ┆ Gentoo    ┆ 4700.0       │
#  │ Torgersen ┆ Female ┆ Adelie    ┆ 3450.0       │
#  │ Biscoe    ┆ Male   ┆ Adelie    ┆ 4050.0       │
#  │ Dream     ┆ Male   ┆ Adelie    ┆ 4000.0       │
#  │ Dream     ┆ Female ┆ Chinstrap ┆ 3575.0       │
#  └───────────┴────────┴───────────┴──────────────┘,
#  'req_33': shape: (5, 3)
#  ┌───────────┬───────────┬──────────────┐
#  │ island    ┆ species   ┆ quantile_0.5 │
#  │ ---       ┆ ---       ┆ ---          │
#  │ str       ┆ str       ┆ f64          │
#  ╞═══════════╪═══════════╪══════════════╡
#  │ Dream     ┆ Chinstrap ┆ 3700.0       │
#  │ Dream     ┆ Adelie    ┆ 3600.0       │
#  │ Torgersen ┆ Adelie    ┆ 3700.0       │
#  │ Biscoe    ┆ Adelie    ┆ 3750.0       │
#  │ Biscoe    ┆ Gentoo    ┆ 5050.0       │
#  └───────────┴───────────┴──────────────┘}

# %%
from src.pipeline_class import Pipeline

pipeline_request = Pipeline(requetes, lf)
# pipeline_request.execute()
X = pipeline_request.precision_dp(budget_global=0.1, dict_poids=dict_poids)
print(X)
# Out:
# ==> Début precision_dp
# <== Fin precision_dp (temps total : 0.22 secondes)
# {'Comptage': shape: (8, 4)
# ┌─────────┬──────────────────────────────┬───────────────────────┬──────────────────┐
# │ requête ┆ groupement                   ┆ écart type estimation ┆ écart type bruit │
# │ ---     ┆ ---                          ┆ ---                   ┆ ---              │
# │ str     ┆ str                          ┆ f64                   ┆ f64              │
# ╞═════════╪══════════════════════════════╪═══════════════════════╪══════════════════╡
# │ req_1   ┆ Aucun                        ┆ 4.1                   ┆ 6.4              │
# │ req_2   ┆ species                      ┆ 4.2                   ┆ 6.4              │
# │ req_3   ┆ ('island', 'species')        ┆ 4.0                   ┆ 6.4              │
# │ req_4   ┆ ('island', 'sex', 'species') ┆ 4.0                   ┆ 6.4              │
# │ req_5   ┆ ('island', 'sex')            ┆ 4.0                   ┆ 6.4              │
# │ req_6   ┆ sex                          ┆ 4.1                   ┆ 6.4              │
# │ req_7   ┆ island                       ┆ 4.2                   ┆ 7.4              │
# │ req_8   ┆ ('sex', 'species')           ┆ 4.7                   ┆ 9.1              │
# └─────────┴──────────────────────────────┴───────────────────────┴──────────────────┘, 'Total': shape: (8, 10)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ requête ┆ variable   ┆ groupemen ┆ cv moyen  ┆ … ┆ écart     ┆ écart     ┆ écart     ┆ écart     │
# │ ---     ┆ ---        ┆ t         ┆ (%)       ┆   ┆ type      ┆ type      ┆ type      ┆ type      │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ total     ┆ comptage  ┆ bruit     ┆ bruit     │
# │         ┆            ┆ str       ┆ f64       ┆   ┆ centré    ┆ ---       ┆ total     ┆ comptage  │
# │         ┆            ┆           ┆           ┆   ┆ ---       ┆ f64       ┆ centré    ┆ ---       │
# │         ┆            ┆           ┆           ┆   ┆ f64       ┆           ┆ ---       ┆ f64       │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆           │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ req_9   ┆ body_mass_ ┆ Aucun     ┆ 1.4       ┆ … ┆ 8538.1    ┆ 4.1       ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_10  ┆ body_mass_ ┆ species   ┆ 5.2       ┆ … ┆ 8909.5    ┆ 4.2       ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_11  ┆ body_mass_ ┆ ('island' ┆ 8.9       ┆ … ┆ 8339.1    ┆ 4.0       ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆ , 'specie ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ s')       ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_12  ┆ body_mass_ ┆ ('island' ┆ 18.1      ┆ … ┆ 8517.2    ┆ 4.0       ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆ , 'sex',  ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 'species' ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ )         ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_13  ┆ body_mass_ ┆ ('island' ┆ 12.3      ┆ … ┆ 8411.9    ┆ 4.0       ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆ , 'sex')  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_14  ┆ body_mass_ ┆ sex       ┆ 2.9       ┆ … ┆ 8689.3    ┆ 4.1       ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_15  ┆ body_mass_ ┆ ('sex',   ┆ 11.9      ┆ … ┆ 10738.2   ┆ 4.7       ┆ 23121.4   ┆ 9.1       │
# │         ┆ g          ┆ 'species' ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ )         ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_16  ┆ body_mass_ ┆ island    ┆ 6.4       ┆ … ┆ 8909.5    ┆ 4.2       ┆ 16349.3   ┆ 7.4       │
# │         ┆ g          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘, 'Moyenne': shape: (7, 11)
# ┌─────────┬────────────┬────────────┬────────────┬───┬────────────┬────────┬───────────┬───────────┐
# │ requête ┆ variable   ┆ groupement ┆ cv moyen   ┆ … ┆ écart type ┆ écart  ┆ écart     ┆ écart     │
# │ ---     ┆ ---        ┆ ---        ┆ (%)        ┆   ┆ comptage   ┆ type   ┆ type      ┆ type      │
# │ str     ┆ str        ┆ str        ┆ ---        ┆   ┆ ---        ┆ total  ┆ bruit     ┆ bruit     │
# │         ┆            ┆            ┆ f64        ┆   ┆ f64        ┆ centré ┆ total     ┆ comptage  │
# │         ┆            ┆            ┆            ┆   ┆            ┆ ---    ┆ centré    ┆ ---       │
# │         ┆            ┆            ┆            ┆   ┆            ┆ f64    ┆ ---       ┆ f64       │
# │         ┆            ┆            ┆            ┆   ┆            ┆        ┆ f64       ┆           │
# ╞═════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════╪═══════════╪═══════════╡
# │ req_17  ┆ body_mass_ ┆ Aucun      ┆ 0.6        ┆ … ┆ 4.1        ┆ 8538.1 ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆            ┆            ┆   ┆            ┆        ┆           ┆           │
# │ req_18  ┆ body_mass_ ┆ species    ┆ 2.3        ┆ … ┆ 4.2        ┆ 8909.5 ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆            ┆            ┆   ┆            ┆        ┆           ┆           │
# │ req_19  ┆ body_mass_ ┆ ('island', ┆ 4.0        ┆ … ┆ 4.0        ┆ 8339.1 ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆ 'species') ┆            ┆   ┆            ┆        ┆           ┆           │
# │ req_20  ┆ body_mass_ ┆ ('island', ┆ 8.1        ┆ … ┆ 4.0        ┆ 8517.2 ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆ 'sex',     ┆            ┆   ┆            ┆        ┆           ┆           │
# │         ┆            ┆ 'species') ┆            ┆   ┆            ┆        ┆           ┆           │
# │ req_21  ┆ body_mass_ ┆ ('island', ┆ 5.4        ┆ … ┆ 4.0        ┆ 8411.9 ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆ 'sex')     ┆            ┆   ┆            ┆        ┆           ┆           │
# │ req_22  ┆ body_mass_ ┆ sex        ┆ 1.3        ┆ … ┆ 4.1        ┆ 8689.3 ┆ 13349.2   ┆ 6.4       │
# │         ┆ g          ┆            ┆            ┆   ┆            ┆        ┆           ┆           │
# │ req_23  ┆ body_mass_ ┆ island     ┆ 2.9        ┆ … ┆ 4.2        ┆ 8909.5 ┆ 16349.3   ┆ 7.4       │
# │         ┆ g          ┆            ┆            ┆   ┆            ┆        ┆           ┆           │
# └─────────┴────────────┴────────────┴────────────┴───┴────────────┴────────┴───────────┴───────────┘, 'Ratio': shape: (6, 15)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ requête ┆ variable   ┆ variable  ┆ groupemen ┆ … ┆ écart     ┆ écart     ┆ écart     ┆ écart     │
# │ ---     ┆ numérateur ┆ dénominat ┆ t         ┆   ┆ type      ┆ type      ┆ type      ┆ type      │
# │ str     ┆ ---        ┆ eur       ┆ ---       ┆   ┆ comptage  ┆ bruit     ┆ bruit     ┆ bruit     │
# │         ┆ str        ┆ ---       ┆ str       ┆   ┆ ---       ┆ total     ┆ total     ┆ comptage  │
# │         ┆            ┆ str       ┆           ┆   ┆ f64       ┆ numérat…  ┆ dénomin…  ┆ ---       │
# │         ┆            ┆           ┆           ┆   ┆           ┆ ---       ┆ ---       ┆ f64       │
# │         ┆            ┆           ┆           ┆   ┆           ┆ f64       ┆ f64       ┆           │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ req_24  ┆ body_mass_ ┆ bill_leng ┆ species   ┆ … ┆ 4.2       ┆ 13349.2   ┆ 176.6     ┆ 6.4       │
# │         ┆ g          ┆ th_mm     ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_25  ┆ body_mass_ ┆ bill_leng ┆ ('island' ┆ … ┆ 4.0       ┆ 13349.2   ┆ 176.6     ┆ 6.4       │
# │         ┆ g          ┆ th_mm     ┆ , 'specie ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ s')       ┆   ┆           ┆           ┆           ┆           │
# │ req_26  ┆ body_mass_ ┆ bill_leng ┆ ('island' ┆ … ┆ 4.0       ┆ 13349.2   ┆ 176.6     ┆ 6.4       │
# │         ┆ g          ┆ th_mm     ┆ , 'sex',  ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ 'species' ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ )         ┆   ┆           ┆           ┆           ┆           │
# │ req_27  ┆ body_mass_ ┆ bill_leng ┆ ('island' ┆ … ┆ 4.0       ┆ 13349.2   ┆ 176.6     ┆ 6.4       │
# │         ┆ g          ┆ th_mm     ┆ , 'sex')  ┆   ┆           ┆           ┆           ┆           │
# │ req_28  ┆ body_mass_ ┆ bill_leng ┆ sex       ┆ … ┆ 4.1       ┆ 13349.2   ┆ 176.6     ┆ 6.4       │
# │         ┆ g          ┆ th_mm     ┆           ┆   ┆           ┆           ┆           ┆           │
# │ req_29  ┆ body_mass_ ┆ bill_leng ┆ Aucun     ┆ … ┆ 4.1       ┆ 13349.2   ┆ 176.6     ┆ 6.4       │
# │         ┆ g          ┆ th_mm     ┆           ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘, 'Quantile': shape: (4, 5)
# ┌─────────┬─────────────┬──────────┬──────────────────────────────┬───────────────────────┐
# │ requête ┆ variable    ┆ quantile ┆ groupement                   ┆ taille moyenne IC 95% │
# │ ---     ┆ ---         ┆ ---      ┆ ---                          ┆ ---                   │
# │ str     ┆ str         ┆ str      ┆ str                          ┆ f64                   │
# ╞═════════╪═════════════╪══════════╪══════════════════════════════╪═══════════════════════╡
# │ req_30  ┆ body_mass_g ┆ Q2       ┆ Aucun                        ┆ 288.0                 │
# │ req_31  ┆ body_mass_g ┆ Q2       ┆ species                      ┆ 988.0                 │
# │ req_32  ┆ body_mass_g ┆ Q2       ┆ ('island', 'sex', 'species') ┆ 3584.4                │
# │ req_33  ┆ body_mass_g ┆ Q2       ┆ ('island', 'species')        ┆ 2587.2                │
# └─────────┴─────────────┴──────────┴──────────────────────────────┴───────────────────────┘}

# %%
from src.pipeline_class import Pipeline

pipeline_request = Pipeline(requetes, lf)
X = pipeline_request.execute_dp(budget_global=0.1, dict_poids=dict_poids)
print(X)
# Out:
# ==> Début execute_dp
# ✅ Context terminée en 0.04 secondes.
# <== Fin execute_dp (temps total : 24.27 secondes)
# {'req_1': shape: (1, 1)
# ┌───────┐
# │ count │
# │ ---   │
# │ f64   │
# ╞═══════╡
# │ 331.3 │
# └───────┘, 'req_2': shape: (3, 2)
# ┌───────────┬───────┐
# │ species   ┆ count │
# │ ---       ┆ ---   │
# │ str       ┆ f64   │
# ╞═══════════╪═══════╡
# │ Adelie    ┆ 148.5 │
# │ Chinstrap ┆ 62.2  │
# │ Gentoo    ┆ 120.6 │
# └───────────┴───────┘, 'req_3': shape: (9, 3)
# ┌───────────┬───────────┬───────┐
# │ island    ┆ species   ┆ count │
# │ ---       ┆ ---       ┆ ---   │
# │ str       ┆ str       ┆ f64   │
# ╞═══════════╪═══════════╪═══════╡
# │ Biscoe    ┆ Adelie    ┆ 45.3  │
# │ Biscoe    ┆ Chinstrap ┆ 2.1   │
# │ Biscoe    ┆ Gentoo    ┆ 116.1 │
# │ Dream     ┆ Adelie    ┆ 59.4  │
# │ Dream     ┆ Chinstrap ┆ 59.8  │
# │ Dream     ┆ Gentoo    ┆ 1.9   │
# │ Torgersen ┆ Adelie    ┆ 43.8  │
# │ Torgersen ┆ Chinstrap ┆ 0.3   │
# │ Torgersen ┆ Gentoo    ┆ 2.7   │
# └───────────┴───────────┴───────┘, 'req_4': shape: (18, 4)
# ┌───────────┬────────┬───────────┬───────┐
# │ island    ┆ sex    ┆ species   ┆ count │
# │ ---       ┆ ---    ┆ ---       ┆ ---   │
# │ str       ┆ str    ┆ str       ┆ f64   │
# ╞═══════════╪════════╪═══════════╪═══════╡
# │ Biscoe    ┆ Female ┆ Adelie    ┆ 22.2  │
# │ Biscoe    ┆ Female ┆ Chinstrap ┆ 0.0   │
# │ Biscoe    ┆ Female ┆ Gentoo    ┆ 60.1  │
# │ Biscoe    ┆ Male   ┆ Adelie    ┆ 23.1  │
# │ Biscoe    ┆ Male   ┆ Chinstrap ┆ 2.1   │
# │ …         ┆ …      ┆ …         ┆ …     │
# │ Torgersen ┆ Female ┆ Chinstrap ┆ 0.3   │
# │ Torgersen ┆ Female ┆ Gentoo    ┆ 0.0   │
# │ Torgersen ┆ Male   ┆ Adelie    ┆ 20.0  │
# │ Torgersen ┆ Male   ┆ Chinstrap ┆ 0.0   │
# │ Torgersen ┆ Male   ┆ Gentoo    ┆ 2.7   │
# └───────────┴────────┴───────────┴───────┘, 'req_5': shape: (6, 3)
# ┌───────────┬────────┬───────┐
# │ island    ┆ sex    ┆ count │
# │ ---       ┆ ---    ┆ ---   │
# │ str       ┆ str    ┆ f64   │
# ╞═══════════╪════════╪═══════╡
# │ Biscoe    ┆ Female ┆ 82.3  │
# │ Biscoe    ┆ Male   ┆ 81.2  │
# │ Dream     ┆ Female ┆ 62.2  │
# │ Dream     ┆ Male   ┆ 58.9  │
# │ Torgersen ┆ Female ┆ 24.1  │
# │ Torgersen ┆ Male   ┆ 22.6  │
# └───────────┴────────┴───────┘, 'req_6': shape: (2, 2)
# ┌────────┬───────┐
# │ sex    ┆ count │
# │ ---    ┆ ---   │
# │ str    ┆ f64   │
# ╞════════╪═══════╡
# │ Female ┆ 168.6 │
# │ Male   ┆ 162.7 │
# └────────┴───────┘, 'req_7': shape: (3, 2)
# ┌───────────┬───────┐
# │ island    ┆ count │
# │ ---       ┆ ---   │
# │ str       ┆ f64   │
# ╞═══════════╪═══════╡
# │ Biscoe    ┆ 163.5 │
# │ Dream     ┆ 121.1 │
# │ Torgersen ┆ 46.8  │
# └───────────┴───────┘, 'req_8': shape: (6, 3)
# ┌────────┬───────────┬───────┐
# │ sex    ┆ species   ┆ count │
# │ ---    ┆ ---       ┆ ---   │
# │ str    ┆ str       ┆ f64   │
# ╞════════╪═══════════╪═══════╡
# │ Female ┆ Adelie    ┆ 78.8  │
# │ Female ┆ Chinstrap ┆ 28.8  │
# │ Female ┆ Gentoo    ┆ 61.0  │
# │ Male   ┆ Adelie    ┆ 69.7  │
# │ Male   ┆ Chinstrap ┆ 33.4  │
# │ Male   ┆ Gentoo    ┆ 59.6  │
# └────────┴───────────┴───────┘, 'req_9': shape: (1, 2)
# ┌───────────┬───────┐
# │ sum       ┆ count │
# │ ---       ┆ ---   │
# │ f64       ┆ f64   │
# ╞═══════════╪═══════╡
# │ 1382148.7 ┆ 331.3 │
# └───────────┴───────┘, 'req_10': shape: (3, 3)
# ┌───────────┬──────────┬───────┐
# │ species   ┆ sum      ┆ count │
# │ ---       ┆ ---      ┆ ---   │
# │ str       ┆ f64      ┆ f64   │
# ╞═══════════╪══════════╪═══════╡
# │ Adelie    ┆ 560325.6 ┆ 148.5 │
# │ Chinstrap ┆ 217324.6 ┆ 62.2  │
# │ Gentoo    ┆ 604498.5 ┆ 120.6 │
# └───────────┴──────────┴───────┘, 'req_11': shape: (9, 4)
# ┌───────────┬───────────┬──────────┬───────┐
# │ island    ┆ species   ┆ sum      ┆ count │
# │ ---       ┆ ---       ┆ ---      ┆ ---   │
# │ str       ┆ str       ┆ f64      ┆ f64   │
# ╞═══════════╪═══════════╪══════════╪═══════╡
# │ Biscoe    ┆ Adelie    ┆ 178061.9 ┆ 45.3  │
# │ Biscoe    ┆ Chinstrap ┆ 3605.7   ┆ 2.1   │
# │ Biscoe    ┆ Gentoo    ┆ 577353.6 ┆ 116.1 │
# │ Dream     ┆ Adelie    ┆ 214257.8 ┆ 59.4  │
# │ Dream     ┆ Chinstrap ┆ 223800.6 ┆ 59.8  │
# │ Dream     ┆ Gentoo    ┆ -251.6   ┆ 1.9   │
# │ Torgersen ┆ Adelie    ┆ 168005.9 ┆ 43.8  │
# │ Torgersen ┆ Chinstrap ┆ -10081.8 ┆ 0.3   │
# │ Torgersen ┆ Gentoo    ┆ 27396.5  ┆ 2.7   │
# └───────────┴───────────┴──────────┴───────┘, 'req_12': shape: (18, 5)
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │ island    ┆ sex    ┆ species   ┆ sum      ┆ count │
# │ ---       ┆ ---    ┆ ---       ┆ ---      ┆ ---   │
# │ str       ┆ str    ┆ str       ┆ f64      ┆ f64   │
# ╞═══════════╪════════╪═══════════╪══════════╪═══════╡
# │ Biscoe    ┆ Female ┆ Adelie    ┆ 78492.3  ┆ 22.2  │
# │ Biscoe    ┆ Female ┆ Chinstrap ┆ 7290.5   ┆ 0.0   │
# │ Biscoe    ┆ Female ┆ Gentoo    ┆ 269684.3 ┆ 60.1  │
# │ Biscoe    ┆ Male   ┆ Adelie    ┆ 99569.6  ┆ 23.1  │
# │ Biscoe    ┆ Male   ┆ Chinstrap ┆ -3684.8  ┆ 2.1   │
# │ …         ┆ …      ┆ …         ┆ …        ┆ …     │
# │ Torgersen ┆ Female ┆ Chinstrap ┆ 2135.4   ┆ 0.3   │
# │ Torgersen ┆ Female ┆ Gentoo    ┆ 7051.2   ┆ 0.0   │
# │ Torgersen ┆ Male   ┆ Adelie    ┆ 91917.0  ┆ 20.0  │
# │ Torgersen ┆ Male   ┆ Chinstrap ┆ -12217.2 ┆ 0.0   │
# │ Torgersen ┆ Male   ┆ Gentoo    ┆ 20345.3  ┆ 2.7   │
# └───────────┴────────┴───────────┴──────────┴───────┘, 'req_13': shape: (6, 4)
# ┌───────────┬────────┬──────────┬───────┐
# │ island    ┆ sex    ┆ sum      ┆ count │
# │ ---       ┆ ---    ┆ ---      ┆ ---   │
# │ str       ┆ str    ┆ f64      ┆ f64   │
# ╞═══════════╪════════╪══════════╪═══════╡
# │ Biscoe    ┆ Female ┆ 355467.2 ┆ 82.3  │
# │ Biscoe    ┆ Male   ┆ 403554.1 ┆ 81.2  │
# │ Dream     ┆ Female ┆ 205934.9 ┆ 62.2  │
# │ Dream     ┆ Male   ┆ 231872.0 ┆ 58.9  │
# │ Torgersen ┆ Female ┆ 85275.5  ┆ 24.1  │
# │ Torgersen ┆ Male   ┆ 100045.2 ┆ 22.6  │
# └───────────┴────────┴──────────┴───────┘, 'req_14': shape: (2, 3)
# ┌────────┬──────────┬───────┐
# │ sex    ┆ sum      ┆ count │
# │ ---    ┆ ---      ┆ ---   │
# │ str    ┆ f64      ┆ f64   │
# ╞════════╪══════════╪═══════╡
# │ Female ┆ 646677.5 ┆ 168.6 │
# │ Male   ┆ 735471.3 ┆ 162.7 │
# └────────┴──────────┴───────┘, 'req_15': shape: (6, 4)
# ┌────────┬───────────┬──────────┬───────┐
# │ sex    ┆ species   ┆ sum      ┆ count │
# │ ---    ┆ ---       ┆ ---      ┆ ---   │
# │ str    ┆ str       ┆ f64      ┆ f64   │
# ╞════════╪═══════════╪══════════╪═══════╡
# │ Female ┆ Adelie    ┆ 259529.7 ┆ 78.8  │
# │ Female ┆ Chinstrap ┆ 115038.5 ┆ 28.8  │
# │ Female ┆ Gentoo    ┆ 272109.2 ┆ 61.0  │
# │ Male   ┆ Adelie    ┆ 300795.9 ┆ 69.7  │
# │ Male   ┆ Chinstrap ┆ 102286.0 ┆ 33.4  │
# │ Male   ┆ Gentoo    ┆ 332389.3 ┆ 59.6  │
# └────────┴───────────┴──────────┴───────┘, 'req_16': shape: (3, 3)
# ┌───────────┬──────────┬───────┐
# │ island    ┆ sum      ┆ count │
# │ ---       ┆ ---      ┆ ---   │
# │ str       ┆ f64      ┆ f64   │
# ╞═══════════╪══════════╪═══════╡
# │ Biscoe    ┆ 759021.2 ┆ 163.5 │
# │ Dream     ┆ 437806.9 ┆ 121.1 │
# │ Torgersen ┆ 185320.6 ┆ 46.8  │
# └───────────┴──────────┴───────┘, 'req_17': shape: (1, 3)
# ┌───────────┬───────┬────────┐
# │ sum       ┆ count ┆ mean   │
# │ ---       ┆ ---   ┆ ---    │
# │ f64       ┆ f64   ┆ f64    │
# ╞═══════════╪═══════╪════════╡
# │ 1382148.7 ┆ 331.3 ┆ 4171.7 │
# └───────────┴───────┴────────┘, 'req_18': shape: (3, 4)
# ┌───────────┬──────────┬───────┬────────┐
# │ species   ┆ sum      ┆ count ┆ mean   │
# │ ---       ┆ ---      ┆ ---   ┆ ---    │
# │ str       ┆ f64      ┆ f64   ┆ f64    │
# ╞═══════════╪══════════╪═══════╪════════╡
# │ Adelie    ┆ 560325.6 ┆ 148.5 ┆ 3773.0 │
# │ Chinstrap ┆ 217324.6 ┆ 62.2  ┆ 3494.0 │
# │ Gentoo    ┆ 604498.5 ┆ 120.6 ┆ 5011.9 │
# └───────────┴──────────┴───────┴────────┘, 'req_19': shape: (9, 5)
# ┌───────────┬───────────┬──────────┬───────┬──────────┐
# │ island    ┆ species   ┆ sum      ┆ count ┆ mean     │
# │ ---       ┆ ---       ┆ ---      ┆ ---   ┆ ---      │
# │ str       ┆ str       ┆ f64      ┆ f64   ┆ f64      │
# ╞═══════════╪═══════════╪══════════╪═══════╪══════════╡
# │ Biscoe    ┆ Adelie    ┆ 178061.9 ┆ 45.3  ┆ 3930.9   │
# │ Biscoe    ┆ Chinstrap ┆ 3605.7   ┆ 2.1   ┆ 1698.1   │
# │ Biscoe    ┆ Gentoo    ┆ 577353.6 ┆ 116.1 ┆ 4975.0   │
# │ Dream     ┆ Adelie    ┆ 214257.8 ┆ 59.4  ┆ 3604.0   │
# │ Dream     ┆ Chinstrap ┆ 223800.6 ┆ 59.8  ┆ 3744.7   │
# │ Dream     ┆ Gentoo    ┆ -251.6   ┆ 1.9   ┆ -134.5   │
# │ Torgersen ┆ Adelie    ┆ 168005.9 ┆ 43.8  ┆ 3839.3   │
# │ Torgersen ┆ Chinstrap ┆ -10081.8 ┆ 0.3   ┆ -32351.3 │
# │ Torgersen ┆ Gentoo    ┆ 27396.5  ┆ 2.7   ┆ 10181.2  │
# └───────────┴───────────┴──────────┴───────┴──────────┘, 'req_20': shape: (18, 6)
# ┌───────────┬────────┬───────────┬──────────┬───────┬────────────┐
# │ island    ┆ sex    ┆ species   ┆ sum      ┆ count ┆ mean       │
# │ ---       ┆ ---    ┆ ---       ┆ ---      ┆ ---   ┆ ---        │
# │ str       ┆ str    ┆ str       ┆ f64      ┆ f64   ┆ f64        │
# ╞═══════════╪════════╪═══════════╪══════════╪═══════╪════════════╡
# │ Biscoe    ┆ Female ┆ Adelie    ┆ 78492.3  ┆ 22.2  ┆ 3529.8     │
# │ Biscoe    ┆ Female ┆ Chinstrap ┆ 7290.5   ┆ 0.0   ┆ -6.4957e23 │
# │ Biscoe    ┆ Female ┆ Gentoo    ┆ 269684.3 ┆ 60.1  ┆ 4489.0     │
# │ Biscoe    ┆ Male   ┆ Adelie    ┆ 99569.6  ┆ 23.1  ┆ 4317.7     │
# │ Biscoe    ┆ Male   ┆ Chinstrap ┆ -3684.8  ┆ 2.1   ┆ -1735.3    │
# │ …         ┆ …      ┆ …         ┆ …        ┆ …     ┆ …          │
# │ Torgersen ┆ Female ┆ Chinstrap ┆ 2135.4   ┆ 0.3   ┆ 6852.4     │
# │ Torgersen ┆ Female ┆ Gentoo    ┆ 7051.2   ┆ 0.0   ┆ -5.3301e23 │
# │ Torgersen ┆ Male   ┆ Adelie    ┆ 91917.0  ┆ 20.0  ┆ 4606.7     │
# │ Torgersen ┆ Male   ┆ Chinstrap ┆ -12217.2 ┆ 0.0   ┆ -5.5717e25 │
# │ Torgersen ┆ Male   ┆ Gentoo    ┆ 20345.3  ┆ 2.7   ┆ 7560.8     │
# └───────────┴────────┴───────────┴──────────┴───────┴────────────┘, 'req_21': shape: (6, 5)
# ┌───────────┬────────┬──────────┬───────┬────────┐
# │ island    ┆ sex    ┆ sum      ┆ count ┆ mean   │
# │ ---       ┆ ---    ┆ ---      ┆ ---   ┆ ---    │
# │ str       ┆ str    ┆ f64      ┆ f64   ┆ f64    │
# ╞═══════════╪════════╪══════════╪═══════╪════════╡
# │ Biscoe    ┆ Female ┆ 355467.2 ┆ 82.3  ┆ 4318.5 │
# │ Biscoe    ┆ Male   ┆ 403554.1 ┆ 81.2  ┆ 4972.3 │
# │ Dream     ┆ Female ┆ 205934.9 ┆ 62.2  ┆ 3312.1 │
# │ Dream     ┆ Male   ┆ 231872.0 ┆ 58.9  ┆ 3936.3 │
# │ Torgersen ┆ Female ┆ 85275.5  ┆ 24.1  ┆ 3535.6 │
# │ Torgersen ┆ Male   ┆ 100045.2 ┆ 22.6  ┆ 4418.2 │
# └───────────┴────────┴──────────┴───────┴────────┘, 'req_22': shape: (2, 4)
# ┌────────┬──────────┬───────┬────────┐
# │ sex    ┆ sum      ┆ count ┆ mean   │
# │ ---    ┆ ---      ┆ ---   ┆ ---    │
# │ str    ┆ f64      ┆ f64   ┆ f64    │
# ╞════════╪══════════╪═══════╪════════╡
# │ Female ┆ 646677.5 ┆ 168.6 ┆ 3835.4 │
# │ Male   ┆ 735471.3 ┆ 162.7 ┆ 4520.1 │
# └────────┴──────────┴───────┴────────┘, 'req_23': shape: (3, 4)
# ┌───────────┬──────────┬───────┬────────┐
# │ island    ┆ sum      ┆ count ┆ mean   │
# │ ---       ┆ ---      ┆ ---   ┆ ---    │
# │ str       ┆ f64      ┆ f64   ┆ f64    │
# ╞═══════════╪══════════╪═══════╪════════╡
# │ Biscoe    ┆ 759021.2 ┆ 163.5 ┆ 4643.1 │
# │ Dream     ┆ 437806.9 ┆ 121.1 ┆ 3615.7 │
# │ Torgersen ┆ 185320.6 ┆ 46.8  ┆ 3963.0 │
# └───────────┴──────────┴───────┴────────┘, 'req_24': shape: (3, 5)
# ┌───────────┬──────────┬───────────┬───────┬───────┐
# │ species   ┆ sum_num  ┆ sum_denom ┆ count ┆ ratio │
# │ ---       ┆ ---      ┆ ---       ┆ ---   ┆ ---   │
# │ str       ┆ f64      ┆ f64       ┆ f64   ┆ f64   │
# ╞═══════════╪══════════╪═══════════╪═══════╪═══════╡
# │ Adelie    ┆ 560325.6 ┆ 5654.3    ┆ 148.5 ┆ 99.1  │
# │ Chinstrap ┆ 217324.6 ┆ 2907.0    ┆ 62.2  ┆ 74.8  │
# │ Gentoo    ┆ 604498.5 ┆ 5893.8    ┆ 120.6 ┆ 102.6 │
# └───────────┴──────────┴───────────┴───────┴───────┘, 'req_25': shape: (9, 6)
# ┌───────────┬───────────┬──────────┬───────────┬───────┬───────┐
# │ island    ┆ species   ┆ sum_num  ┆ sum_denom ┆ count ┆ ratio │
# │ ---       ┆ ---       ┆ ---      ┆ ---       ┆ ---   ┆ ---   │
# │ str       ┆ str       ┆ f64      ┆ f64       ┆ f64   ┆ f64   │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══════╪═══════╡
# │ Biscoe    ┆ Adelie    ┆ 178061.9 ┆ 1715.6    ┆ 45.3  ┆ 103.8 │
# │ Biscoe    ┆ Chinstrap ┆ 3605.7   ┆ 80.8      ┆ 2.1   ┆ 44.6  │
# │ Biscoe    ┆ Gentoo    ┆ 577353.6 ┆ 5579.0    ┆ 116.1 ┆ 103.5 │
# │ Dream     ┆ Adelie    ┆ 214257.8 ┆ 2289.4    ┆ 59.4  ┆ 93.6  │
# │ Dream     ┆ Chinstrap ┆ 223800.6 ┆ 2866.2    ┆ 59.8  ┆ 78.1  │
# │ Dream     ┆ Gentoo    ┆ -251.6   ┆ 198.9     ┆ 1.9   ┆ -1.3  │
# │ Torgersen ┆ Adelie    ┆ 168005.9 ┆ 1649.3    ┆ 43.8  ┆ 101.9 │
# │ Torgersen ┆ Chinstrap ┆ -10081.8 ┆ -40.0     ┆ 0.3   ┆ 252.3 │
# │ Torgersen ┆ Gentoo    ┆ 27396.5  ┆ 115.9     ┆ 2.7   ┆ 236.3 │
# └───────────┴───────────┴──────────┴───────────┴───────┴───────┘, 'req_26': shape: (18, 7)
# ┌───────────┬────────┬───────────┬──────────┬───────────┬───────┬────────┐
# │ island    ┆ sex    ┆ species   ┆ sum_num  ┆ sum_denom ┆ count ┆ ratio  │
# │ ---       ┆ ---    ┆ ---       ┆ ---      ┆ ---       ┆ ---   ┆ ---    │
# │ str       ┆ str    ┆ str       ┆ f64      ┆ f64       ┆ f64   ┆ f64    │
# ╞═══════════╪════════╪═══════════╪══════════╪═══════════╪═══════╪════════╡
# │ Biscoe    ┆ Female ┆ Adelie    ┆ 78492.3  ┆ 509.3     ┆ 22.2  ┆ 154.1  │
# │ Biscoe    ┆ Female ┆ Chinstrap ┆ 7290.5   ┆ 15.4      ┆ 0.0   ┆ 472.8  │
# │ Biscoe    ┆ Female ┆ Gentoo    ┆ 269684.3 ┆ 2945.1    ┆ 60.1  ┆ 91.6   │
# │ Biscoe    ┆ Male   ┆ Adelie    ┆ 99569.6  ┆ 1206.3    ┆ 23.1  ┆ 82.5   │
# │ Biscoe    ┆ Male   ┆ Chinstrap ┆ -3684.8  ┆ 65.3      ┆ 2.1   ┆ -56.4  │
# │ …         ┆ …      ┆ …         ┆ …        ┆ …         ┆ …     ┆ …      │
# │ Torgersen ┆ Female ┆ Chinstrap ┆ 2135.4   ┆ 26.2      ┆ 0.3   ┆ 81.5   │
# │ Torgersen ┆ Female ┆ Gentoo    ┆ 7051.2   ┆ -33.6     ┆ 0.0   ┆ -209.9 │
# │ Torgersen ┆ Male   ┆ Adelie    ┆ 91917.0  ┆ 784.5     ┆ 20.0  ┆ 117.2  │
# │ Torgersen ┆ Male   ┆ Chinstrap ┆ -12217.2 ┆ -66.2     ┆ 0.0   ┆ 184.6  │
# │ Torgersen ┆ Male   ┆ Gentoo    ┆ 20345.3  ┆ 149.5     ┆ 2.7   ┆ 136.1  │
# └───────────┴────────┴───────────┴──────────┴───────────┴───────┴────────┘, 'req_27': shape: (6, 6)
# ┌───────────┬────────┬──────────┬───────────┬───────┬───────┐
# │ island    ┆ sex    ┆ sum_num  ┆ sum_denom ┆ count ┆ ratio │
# │ ---       ┆ ---    ┆ ---      ┆ ---       ┆ ---   ┆ ---   │
# │ str       ┆ str    ┆ f64      ┆ f64       ┆ f64   ┆ f64   │
# ╞═══════════╪════════╪══════════╪═══════════╪═══════╪═══════╡
# │ Biscoe    ┆ Female ┆ 355467.2 ┆ 3469.8    ┆ 82.3  ┆ 102.4 │
# │ Biscoe    ┆ Male   ┆ 403554.1 ┆ 3905.5    ┆ 81.2  ┆ 103.3 │
# │ Dream     ┆ Female ┆ 205934.9 ┆ 2620.5    ┆ 62.2  ┆ 78.6  │
# │ Dream     ┆ Male   ┆ 231872.0 ┆ 2734.0    ┆ 58.9  ┆ 84.8  │
# │ Torgersen ┆ Female ┆ 85275.5  ┆ 857.5     ┆ 24.1  ┆ 99.5  │
# │ Torgersen ┆ Male   ┆ 100045.2 ┆ 867.8     ┆ 22.6  ┆ 115.3 │
# └───────────┴────────┴──────────┴───────────┴───────┴───────┘, 'req_28': shape: (2, 5)
# ┌────────┬──────────┬───────────┬───────┬───────┐
# │ sex    ┆ sum_num  ┆ sum_denom ┆ count ┆ ratio │
# │ ---    ┆ ---      ┆ ---       ┆ ---   ┆ ---   │
# │ str    ┆ f64      ┆ f64       ┆ f64   ┆ f64   │
# ╞════════╪══════════╪═══════════╪═══════╪═══════╡
# │ Female ┆ 646677.5 ┆ 6947.8    ┆ 168.6 ┆ 93.1  │
# │ Male   ┆ 735471.3 ┆ 7507.3    ┆ 162.7 ┆ 98.0  │
# └────────┴──────────┴───────────┴───────┴───────┘, 'req_29': shape: (1, 4)
# ┌───────────┬───────────┬───────┬───────┐
# │ sum_num   ┆ sum_denom ┆ count ┆ ratio │
# │ ---       ┆ ---       ┆ ---   ┆ ---   │
# │ f64       ┆ f64       ┆ f64   ┆ f64   │
# ╞═══════════╪═══════════╪═══════╪═══════╡
# │ 1382148.7 ┆ 14455.1   ┆ 331.3 ┆ 95.6  │
# └───────────┴───────────┴───────┴───────┘, 'req_30': shape: (1, 1)
# ┌──────────────┐
# │ quantile_0.5 │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ 4614.4       │
# └──────────────┘, 'req_31': shape: (3, 2)
# ┌───────────┬──────────────┐
# │ species   ┆ quantile_0.5 │
# │ ---       ┆ ---          │
# │ str       ┆ f64          │
# ╞═══════════╪══════════════╡
# │ Adelie    ┆ 5661.9       │
# │ Chinstrap ┆ 2820.4       │
# │ Gentoo    ┆ 2808.4       │
# └───────────┴──────────────┘, 'req_32': shape: (18, 4)
# ┌───────────┬────────┬───────────┬──────────────┐
# │ island    ┆ sex    ┆ species   ┆ quantile_0.5 │
# │ ---       ┆ ---    ┆ ---       ┆ ---          │
# │ str       ┆ str    ┆ str       ┆ f64          │
# ╞═══════════╪════════╪═══════════╪══════════════╡
# │ Biscoe    ┆ Female ┆ Adelie    ┆ 3410.4       │
# │ Biscoe    ┆ Female ┆ Chinstrap ┆ 5902.7       │
# │ Biscoe    ┆ Female ┆ Gentoo    ┆ 6119.4       │
# │ Biscoe    ┆ Male   ┆ Adelie    ┆ 3001.0       │
# │ Biscoe    ┆ Male   ┆ Chinstrap ┆ 5493.3       │
# │ …         ┆ …      ┆ …         ┆ …            │
# │ Torgersen ┆ Female ┆ Chinstrap ┆ 4903.3       │
# │ Torgersen ┆ Female ┆ Gentoo    ┆ 3663.2       │
# │ Torgersen ┆ Male   ┆ Adelie    ┆ 3338.1       │
# │ Torgersen ┆ Male   ┆ Chinstrap ┆ 6179.6       │
# │ Torgersen ┆ Male   ┆ Gentoo    ┆ 5384.9       │
# └───────────┴────────┴───────────┴──────────────┘, 'req_33': shape: (9, 3)
# ┌───────────┬───────────┬──────────────┐
# │ island    ┆ species   ┆ quantile_0.5 │
# │ ---       ┆ ---       ┆ ---          │
# │ str       ┆ str       ┆ f64          │
# ╞═══════════╪═══════════╪══════════════╡
# │ Biscoe    ┆ Adelie    ┆ 3530.8       │
# │ Biscoe    ┆ Chinstrap ┆ 3735.5       │
# │ Biscoe    ┆ Gentoo    ┆ 5686.0       │
# │ Dream     ┆ Adelie    ┆ 5348.8       │
# │ Dream     ┆ Chinstrap ┆ 2724.1       │
# │ Dream     ┆ Gentoo    ┆ 3265.9       │
# │ Torgersen ┆ Adelie    ┆ 6203.7       │
# │ Torgersen ┆ Chinstrap ┆ 4325.4       │
# │ Torgersen ┆ Gentoo    ┆ 3663.2       │
# └───────────┴───────────┴──────────────┘}

# %%
from src.request_class import Count

a = Count(by=["region", "age"])
b = Count(by=["age", "region"])
print(a.to_query_dict())
print(b.to_query_dict())
print(a == b)
# Out:
# {'type': 'Comptage', 'by': ['region', 'age']}
# {'type': 'Comptage', 'by': ['age', 'region']}
# True

# %%
import opendp.prelude as dp

dp.enable_features("contrib")

m = Moyenne(variable="body_mass_g", bounds=[2700.0, 6300.0])

context_param = {
    "data": lf,
    "privacy_unit": dp.unit_of(contributions=1),
    "margins": [dp.polars.Margin(max_partition_length=1)],
}

context = dp.Context.compositor(
    **context_param,
    privacy_loss=dp.loss_of(rho=0.5),
    split_by_weights=[1]
)

m.precision_opendp(context=context, key_values=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 import opendp.prelude as dp
#       3 dp.enable_features("contrib")
# ----> 5 m = Moyenne(variable="body_mass_g", bounds=[2700.0, 6300.0])
#       7 context_param = {
#       8     "data": lf,
#       9     "privacy_unit": dp.unit_of(contributions=1),
#      10     "margins": [dp.polars.Margin(max_partition_length=1)],
#      11 }
#      13 context = dp.Context.compositor(
#      14     **context_param,
#      15     privacy_loss=dp.loss_of(rho=0.5),
#      16     split_by_weights=[1]
#      17 )
#
# NameError: name 'Moyenne' is not defined

# %%
import opendp.prelude as dp

dp.enable_features("contrib")

context_param = {
    "data": lf,
    "privacy_unit": dp.unit_of(contributions=1),
    "margins": [dp.polars.Margin(max_partition_length=1)],
}

context = dp.Context.compositor(
    **context_param,
    privacy_loss=dp.loss_of(rho=0.5),
    split_by_weights=[1, 3]
)
print(context)

context_2 = dp.Context.compositor(
    **context_param,
    privacy_loss=dp.loss_of(epsilon=0.5),
    split_by_weights=[1]
)
print(context_2)

test = context.accountant
test.output_measure = "MaxDivergence"

context_3 = dp.Context.compositor(
    **context_param,
    privacy_loss=dp.loss_of(epsilon=0.5),
    split_by_weights=[1],
    domain=
)

print(context_3)
# Out:
# Context(
#     accountant = Measurement(
#         input_domain   = FrameDomain(species: str, island: str, bill_length_mm: f64, bill_depth_mm: f64, flipper_length_mm: f64, body_mass_g: f64, sex: str; margins=[{}]),
#         input_metric   = SymmetricDistance(),
#         output_measure = ZeroConcentratedDivergence),
#     d_in       = 1,
#     d_mids     = [0.125, 0.375])
# Context(
#     accountant = Measurement(
#         input_domain   = FrameDomain(species: str, island: str, bill_length_mm: f64, bill_depth_mm: f64, flipper_length_mm: f64, body_mass_g: f64, sex: str; margins=[{}]),
#         input_metric   = SymmetricDistance(),
#         output_measure = MaxDivergence),
#     d_in       = 1,
#     d_mids     = [0.5])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 26
#      23 print(context_2)
#      25 test = context.accountant
# ---> 26 test.output_measure = "MaxDivergence"
#      28 context_3 = dp.Context(
#      29     accountant=test,
#      30     queryable=context.queryable,
#      31     d_in=1,
#      32     d_mids=[0.5]
#      33 )
#      35 print(context_3)
#
# AttributeError: property 'output_measure' of 'Measurement' object has no setter

# %%
import polars as pl
import os 
import opendp.prelude as dp

dp.enable_features("contrib")

# %pip install polars==1.12.0

storage_options = {
    "aws_access_key_id": os.environ["AWS_ACCESS_KEY_ID"],
    "aws_secret_access_key": os.environ["AWS_SECRET_ACCESS_KEY"],
    "aws_session_token": os.environ["AWS_SESSION_TOKEN"],
    "endpoint_url": "https://minio.lab.sspcloud.fr",
}

source = "s3://gferey/diffusion/synthetic-filo/METRO/population/population_METRO.parquet"


lf = pl.read_parquet(source, storage_options=storage_options).drop("geometry").lazy()

# Crée le premier context avec la mesure zCDP (rho)
context_1 = dp.Context.compositor(
    data = lf,
    privacy_unit = dp.unit_of(contributions=1),
    margins = [dp.polars.Margin(max_partition_length=1)],
    privacy_loss=dp.loss_of(rho=0.5),
    split_by_weights=[1, 3]
)
# Out:
# Requirement already satisfied: polars==1.12.0 in /opt/python/lib/python3.13/site-packages (1.12.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
lf_empty = pl.LazyFrame(schema=lf.collect_schema())

context_2_tmp = dp.Context.compositor(
    data=lf_empty,
    privacy_unit=dp.unit_of(contributions=1),
    margins=[dp.polars.Margin(max_partition_length=1)],
    privacy_loss=dp.loss_of(epsilon=0.5),
    split_by_weights=[1]
)

context_2 = dp.Context(
    accountant=context_2_tmp.accountant,
    queryable=context_1.queryable,
    d_in=context_2_tmp.d_in,
    d_mids=context_2_tmp.d_mids
)
print(context_2)
# Out:
# Context(
#     accountant = Measurement(
#         input_domain   = FrameDomain(ID: str, HOUSEHOLD_ID: str, HOUSEHOLD_SIZE: i64, GRD_MENAGE: bool, MONOPARENT: bool, NIVEAU_VIE: f64, TILE_ID: str, AGE_CAT: str, AGE: i64, ADULT: bool, STATUT: str; margins=[{}]),
#         input_metric   = SymmetricDistance(),
#         output_measure = MaxDivergence),
#     d_in       = 1,
#     d_mids     = [0.5])

# %%
print(context_1.queryable.value)
# Out:
# <opendp._lib.AnyObjectPtr object at 0x7f426dc047d0>

# %%
from src.request_class import Count, Sum, Mean, Ratio, Quantile

Quantile(variable = "NIVEAU_VIE", bounds=[0.0,300000.0],alpha=[0.5], nb_candidats="300").execute_dp(context_2, None)
# Out:
# ---------------------------------------------------------------------------
# OpenDPException                           Traceback (most recent call last)
# Cell In[7], line 3
#       1 from src.request_class import Count, Sum, Mean, Ratio, Quantile
# ----> 3 Quantile(variable = "NIVEAU_VIE", bounds=[0.0,300000.0],alpha=[0.5], nb_candidats="300").execute_dp(context_2, None)
#
# File ~/work/diff-privacy-poc/src/request_class.py:162, in Query.execute_dp(self, context, key_values)
#     157 def execute_dp(
#     158     self,
#     159     context: Context,
#     160     key_values
#     161 ):
# --> 162     return self.plan_dp(context, key_values).release().collect()
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:903, in LazyFrameQuery.release(self)
#     901 query = object.__getattribute__(self, "_query")
#     902 resolve = object.__getattribute__(self, "resolve")
# --> 903 return query._context(resolve())
#
# File /opt/python/lib/python3.13/site-packages/opendp/context.py:516, in Context.__call__(self, query)
#     514 def __call__(self, query: Measurement):
#     515     """Executes the given query on the context."""
# --> 516     answer = self.queryable(query)
#     517     if self.d_mids is not None:
#     518         self.d_mids = self.d_mids[1:]
#
# File /opt/python/lib/python3.13/site-packages/opendp/mod.py:512, in Queryable.__call__(self, query)
#     510 def __call__(self, query):
#     511     from opendp.core import queryable_eval
# --> 512     return queryable_eval(self.value, query)
#
# File /opt/python/lib/python3.13/site-packages/opendp/core.py:719, in queryable_eval(queryable, query)
#     716 lib_function.argtypes = [AnyObjectPtr, AnyObjectPtr]
#     717 lib_function.restype = FfiResult
# --> 719 output = c_to_py(unwrap(lib_function(c_queryable, c_query), AnyObjectPtr))
#     720 try:
#     721     output.__opendp_dict__ = {
#     722         '__function__': 'queryable_eval',
#     723         '__module__': 'core',
#    (...)    726         },
#     727     }
#
# File /opt/python/lib/python3.13/site-packages/opendp/_lib.py:282, in unwrap(result, type_)
#     280     if 'polars' in str(message).lower() and pl.__version__ != _EXPECTED_POLARS_VERSION:
#     281         message = f'Installed python polars version ({pl.__version__}) != expected version ({_EXPECTED_POLARS_VERSION}). {message}' # pragma: no cover
# --> 282 raise OpenDPException(variant, message, backtrace)
#
# OpenDPException:
#   MeasureMismatch("Intermediate measures don't match. See https://github.com/opendp/opendp/discussions/297
#     output_measure: ZeroConcentratedDivergence
#     input_measure:  MaxDivergence
# ")

# %%
import polars as pl
import os 

storage_options = {
    "aws_access_key_id": os.environ["AWS_ACCESS_KEY_ID"],
    "aws_secret_access_key": os.environ["AWS_SECRET_ACCESS_KEY"],
    "aws_session_token": os.environ["AWS_SESSION_TOKEN"],
    "endpoint_url": "https://minio.lab.sspcloud.fr",
}

source = "s3://gferey/diffusion/synthetic-filo/METRO/population/population_METRO.parquet"


lf = pl.read_parquet(source, storage_options=storage_options)

# Crée le premier context avec la mesure zCDP (rho)
context_1 = dp.Context.compositor(
    data = lf,
    privacy_unit = dp.unit_of(contributions=1),
    margins = [dp.polars.Margin(max_partition_length=1)],
    privacy_loss=dp.loss_of(rho=0.5),
    split_by_weights=[1, 3],
    domain = context_1.accountant.input_domain
)

# On crée un LazyFrame vide avec le même schéma
lf_empty_same_schema = pl.LazyFrame(schema=lf.collect_schema())

# Réutilise le queryable (déjà construit) dans un second context avec une autre mesure
context_2 = dp.Context.compositor(
    data = lf_empty_same_schema,
    privacy_unit = dp.unit_of(contributions=1),
    margins = [dp.polars.Margin(max_partition_length=1)],
    privacy_loss=dp.loss_of(epsilon=0.5),
    split_by_weights=[1, 3]
)

context_3 = dp.Context(
    accountant=context_2.accountant,
    queryable=context_2.queryable,
    d_in=1,
    d_mids=[0.5]
)

print(context_1)
print(context_2)
print(context_3)
# Out:
# Context(
#     accountant = Measurement(
#         input_domain   = FrameDomain(species: str, island: str, bill_length_mm: f64, bill_depth_mm: f64, flipper_length_mm: f64, body_mass_g: f64, sex: str; margins=[{}]),
#         input_metric   = SymmetricDistance(),
#         output_measure = ZeroConcentratedDivergence),
#     d_in       = 1,
#     d_mids     = [0.125, 0.375])
# Context(
#     accountant = Measurement(
#         input_domain   = FrameDomain(species: str, island: str, bill_length_mm: f64, bill_depth_mm: f64, flipper_length_mm: f64, body_mass_g: f64, sex: str; margins=[{}]),
#         input_metric   = SymmetricDistance(),
#         output_measure = MaxDivergence),
#     d_in       = 1,
#     d_mids     = [0.125, 0.375])
# Context(
#     accountant = Measurement(
#         input_domain   = FrameDomain(species: str, island: str, bill_length_mm: f64, bill_depth_mm: f64, flipper_length_mm: f64, body_mass_g: f64, sex: str; margins=[{}]),
#         input_metric   = SymmetricDistance(),
#         output_measure = MaxDivergence),
#     d_in       = 1,
#     d_mids     = [0.5])
